# %%
import numpy as np
from skimage.io import imread_collection
from skimage.transform import resize
import os
import glob


def get_tiny_images(image_paths):
    # load images
    images = imread_collection(image_paths)

    w_size = h_size = 16
    tiny_images = []

    for image in images:
        # resize to 16*16
        image = resize(image, (w_size, h_size))
        image = (image - np.mean(image)) / np.std(image)
        tiny_images.append(image.flatten())

    return np.array(tiny_images)

def get_image_paths(data_path, categories, num_train_per_cat):
    '''
    This function returns lists containing the file path for each train
    and test image, as well as lists with the label of each train and
    test image. By default both lists will be 1500x1, where each
    entry is a char array (or string).
    '''

    num_categories = len(categories) # number of scene categories.

    # This paths for each training and test image. By default it will have 1500
    # entries (15 categories * 100 training and test examples each)
    train_image_paths = [None] * (num_categories * (num_train_per_cat-30))
    test_image_paths  = [None] * (num_categories * (num_train_per_cat-70))

    # The name of the category for each training and test image. With the
    # default setup, these arrays will actually be the same, but they are built
    # independently for clarity and ease of modification.
    train_labels = [None] * (num_categories * (num_train_per_cat-30))
    test_labels  = [None] * (num_categories * (num_train_per_cat-70))

    for i,cat in enumerate(categories):
        images = glob.glob(os.path.join(data_path, 'training', cat, '*.jpg'))

        for j in range(len(images)):
            if j <=69:
                train_image_paths[i * (num_train_per_cat-30) + j] = images[j]
                train_labels[i * (num_train_per_cat-30) + j] = cat
            else:
                test_image_paths[i*30+j-70] = images[j]
                test_labels[i*30+j-70] = cat
        
#         images = glob.glob(os.path.join(data_path, 'training', cat, '*.jpg'))
#         for j in range(70,num_train_per_cat):

#             test_image_paths[i * num_train_per_cat + j] = images[j]
#             test_labels[i * num_train_per_cat + j] = cat

    return (train_image_paths, train_labels,test_image_paths,test_labels)

# %%
data_path = './'

# This is the list of categories / directories to use. The categories are
# somewhat sorted by similarity so that the confusion matrix looks more
# structured (indoor and then urban and then rural).
categories = ['kitchen', 'store', 'bedroom', 'livingRoom', 'Office',
       'industrial', 'Suburb', 'InsideCity', 'TallBuilding', 'Street',
       'Highway', 'OpenCountry', 'Coast', 'Mountain', 'Forest']

# Number of training examples per category to use. Max is 100. For
# simplicity, we assume this is the number of test cases per category as
# well.
num_train_per_cat = 100

train_image_paths, train_labels, test_image_paths,test_labels = get_image_paths(data_path, categories, num_train_per_cat)

print(test_image_paths)
print(test_labels[0:10])

# for i in range(len(train_image_paths)):
#     print(i)
#     get_tiny_images(train_image_paths[i])

# c = get_tiny_images(train_image_paths[:5])
# Out:
# ['./training\\kitchen\\72.jpg', './training\\kitchen\\73.jpg', './training\\kitchen\\74.jpg', './training\\kitchen\\75.jpg', './training\\kitchen\\76.jpg', './training\\kitchen\\77.jpg', './training\\kitchen\\78.jpg', './training\\kitchen\\79.jpg', './training\\kitchen\\8.jpg', './training\\kitchen\\80.jpg', './training\\kitchen\\81.jpg', './training\\kitchen\\82.jpg', './training\\kitchen\\83.jpg', './training\\kitchen\\84.jpg', './training\\kitchen\\85.jpg', './training\\kitchen\\86.jpg', './training\\kitchen\\87.jpg', './training\\kitchen\\88.jpg', './training\\kitchen\\89.jpg', './training\\kitchen\\9.jpg', './training\\kitchen\\90.jpg', './training\\kitchen\\91.jpg', './training\\kitchen\\92.jpg', './training\\kitchen\\93.jpg', './training\\kitchen\\94.jpg', './training\\kitchen\\95.jpg', './training\\kitchen\\96.jpg', './training\\kitchen\\97.jpg', './training\\kitchen\\98.jpg', './training\\kitchen\\99.jpg', './training\\store\\72.jpg', './training\\store\\73.jpg', './training\\store\\74.jpg', './training\\store\\75.jpg', './training\\store\\76.jpg', './training\\store\\77.jpg', './training\\store\\78.jpg', './training\\store\\79.jpg', './training\\store\\8.jpg', './training\\store\\80.jpg', './training\\store\\81.jpg', './training\\store\\82.jpg', './training\\store\\83.jpg', './training\\store\\84.jpg', './training\\store\\85.jpg', './training\\store\\86.jpg', './training\\store\\87.jpg', './training\\store\\88.jpg', './training\\store\\89.jpg', './training\\store\\9.jpg', './training\\store\\90.jpg', './training\\store\\91.jpg', './training\\store\\92.jpg', './training\\store\\93.jpg', './training\\store\\94.jpg', './training\\store\\95.jpg', './training\\store\\96.jpg', './training\\store\\97.jpg', './training\\store\\98.jpg', './training\\store\\99.jpg', './training\\bedroom\\72.jpg', './training\\bedroom\\73.jpg', './training\\bedroom\\74.jpg', './training\\bedroom\\75.jpg', './training\\bedroom\\76.jpg', './training\\bedroom\\77.jpg', './training\\bedroom\\78.jpg', './training\\bedroom\\79.jpg', './training\\bedroom\\8.jpg', './training\\bedroom\\80.jpg', './training\\bedroom\\81.jpg', './training\\bedroom\\82.jpg', './training\\bedroom\\83.jpg', './training\\bedroom\\84.jpg', './training\\bedroom\\85.jpg', './training\\bedroom\\86.jpg', './training\\bedroom\\87.jpg', './training\\bedroom\\88.jpg', './training\\bedroom\\89.jpg', './training\\bedroom\\9.jpg', './training\\bedroom\\90.jpg', './training\\bedroom\\91.jpg', './training\\bedroom\\92.jpg', './training\\bedroom\\93.jpg', './training\\bedroom\\94.jpg', './training\\bedroom\\95.jpg', './training\\bedroom\\96.jpg', './training\\bedroom\\97.jpg', './training\\bedroom\\98.jpg', './training\\bedroom\\99.jpg', './training\\livingRoom\\72.jpg', './training\\livingRoom\\73.jpg', './training\\livingRoom\\74.jpg', './training\\livingRoom\\75.jpg', './training\\livingRoom\\76.jpg', './training\\livingRoom\\77.jpg', './training\\livingRoom\\78.jpg', './training\\livingRoom\\79.jpg', './training\\livingRoom\\8.jpg', './training\\livingRoom\\80.jpg', './training\\livingRoom\\81.jpg', './training\\livingRoom\\82.jpg', './training\\livingRoom\\83.jpg', './training\\livingRoom\\84.jpg', './training\\livingRoom\\85.jpg', './training\\livingRoom\\86.jpg', './training\\livingRoom\\87.jpg', './training\\livingRoom\\88.jpg', './training\\livingRoom\\89.jpg', './training\\livingRoom\\9.jpg', './training\\livingRoom\\90.jpg', './training\\livingRoom\\91.jpg', './training\\livingRoom\\92.jpg', './training\\livingRoom\\93.jpg', './training\\livingRoom\\94.jpg', './training\\livingRoom\\95.jpg', './training\\livingRoom\\96.jpg', './training\\livingRoom\\97.jpg', './training\\livingRoom\\98.jpg', './training\\livingRoom\\99.jpg', './training\\Office\\72.jpg', './training\\Office\\73.jpg', './training\\Office\\74.jpg', './training\\Office\\75.jpg', './training\\Office\\76.jpg', './training\\Office\\77.jpg', './training\\Office\\78.jpg', './training\\Office\\79.jpg', './training\\Offi ...
# ['kitchen', 'kitchen', 'kitchen', 'kitchen', 'kitchen', 'kitchen', 'kitchen', 'kitchen', 'kitchen', 'kitchen']

# %%
from scipy.spatial.distance import cdist
from collections import Counter

def nearest_neighbor_classify(train_image_feats, train_labels, test_image_feats, k = 1):
    distances = cdist(test_image_feats, train_image_feats, 'euclidean')

    # 1) Find the k closest features to each test image feature in euclidean space
    predictions = []

    for distance in distances:
        k_small_dis_labels = []
        sorted_dis_index = np.argsort(distance)

        # 2) Determine the labels of those k features
        for i in range(k):
            k_small_dis_labels.append(train_labels[sorted_dis_index[i]])
        
        # 3) Pick the most common label from the k
        most_common_label = Counter(k_small_dis_labels).most_common(1)[0][0]

        # 4) Store that label in a list
        predictions.append(most_common_label)

    return np.array(predictions)

train_image_feats = get_tiny_images(train_image_paths)
test_image_feats  = get_tiny_images(test_image_paths)

predicted_categories = nearest_neighbor_classify(train_image_feats, train_labels, test_image_feats)
print(predicted_categories)
# Out:
# ['Suburb' 'kitchen' 'Suburb' 'kitchen' 'Suburb' 'bedroom' 'bedroom'
#  'kitchen' 'bedroom' 'Suburb' 'kitchen' 'kitchen' 'kitchen' 'Suburb'
#  'kitchen' 'kitchen' 'TallBuilding' 'industrial' 'bedroom' 'kitchen'
#  'Suburb' 'Office' 'kitchen' 'kitchen' 'kitchen' 'InsideCity' 'kitchen'
#  'kitchen' 'kitchen' 'Street' 'Suburb' 'Highway' 'store' 'Office'
#  'bedroom' 'livingRoom' 'Suburb' 'kitchen' 'livingRoom' 'kitchen'
#  'kitchen' 'store' 'livingRoom' 'InsideCity' 'InsideCity' 'kitchen'
#  'Mountain' 'Suburb' 'kitchen' 'Forest' 'Mountain' 'Office' 'InsideCity'
#  'Suburb' 'kitchen' 'Suburb' 'industrial' 'InsideCity' 'Office' 'Street'
#  'kitchen' 'bedroom' 'bedroom' 'kitchen' 'bedroom' 'bedroom' 'bedroom'
#  'livingRoom' 'bedroom' 'Suburb' 'Office' 'bedroom' 'TallBuilding'
#  'bedroom' 'bedroom' 'Office' 'bedroom' 'InsideCity' 'kitchen' 'Suburb'
#  'Suburb' 'kitchen' 'bedroom' 'bedroom' 'Suburb' 'Suburb' 'InsideCity'
#  'Suburb' 'Suburb' 'kitchen' 'Street' 'bedroom' 'Suburb' 'InsideCity'
#  'bedroom' 'bedroom' 'livingRoom' 'bedroom' 'store' 'Suburb' 'industrial'
#  'Suburb' 'Suburb' 'Suburb' 'kitchen' 'livingRoom' 'kitchen' 'kitchen'
#  'livingRoom' 'Highway' 'industrial' 'kitchen' 'OpenCountry' 'store'
#  'OpenCountry' 'kitchen' 'kitchen' 'kitchen' 'OpenCountry' 'kitchen'
#  'bedroom' 'bedroom' 'Street' 'InsideCity' 'store' 'kitchen' 'bedroom'
#  'Suburb' 'store' 'store' 'bedroom' 'kitchen' 'InsideCity' 'kitchen'
#  'kitchen' 'Office' 'Office' 'InsideCity' 'Coast' 'industrial' 'Suburb'
#  'bedroom' 'Suburb' 'Suburb' 'livingRoom' 'Office' 'bedroom' 'Office'
#  'kitchen' 'bedroom' 'Highway' 'OpenCountry' 'Suburb' 'InsideCity'
#  'Highway' 'industrial' 'industrial' 'Street' 'livingRoom' 'Suburb'
#  'Mountain' 'kitchen' 'Street' 'Office' 'industrial' 'industrial'
#  'Highway' 'Street' 'industrial' 'livingRoom' 'industrial' 'industrial'
#  'kitchen' 'InsideCity' 'InsideCity' 'Mountain' 'Coast' 'store' 'kitchen'
#  'OpenCountry' 'kitchen' 'OpenCountry' 'InsideCity' 'kitchen' 'store'
#  'OpenCountry' 'kitchen' 'kitchen' 'Office' 'Mountain' 'Suburb' 'Office'
#  'TallBuilding' 'Office' 'livingRoom' 'kitchen' 'kitchen' 'Suburb' 'store'
#  'TallBuilding' 'Office' 'Suburb' 'Office' 'bedroom' 'kitchen' 'Suburb'
#  'OpenCountry' 'Suburb' 'bedroom' 'Office' 'Suburb' 'store' 'InsideCity'
#  'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity'
#  'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity'
#  'InsideCity' 'livingRoom' 'store' 'kitchen' 'store' 'bedroom' 'Office'
#  'TallBuilding' 'InsideCity' 'store' 'InsideCity' 'Office' 'InsideCity'
#  'kitchen' 'kitchen' 'InsideCity' 'Suburb' 'TallBuilding' 'InsideCity'
#  'TallBuilding' 'InsideCity' 'TallBuilding' 'TallBuilding' 'kitchen'
#  'Highway' 'kitchen' 'Mountain' 'TallBuilding' 'InsideCity' 'bedroom'
#  'livingRoom' 'TallBuilding' 'OpenCountry' 'Street' 'TallBuilding'
#  'TallBuilding' 'livingRoom' 'TallBuilding' 'Mountain' 'InsideCity'
#  'industrial' 'kitchen' 'TallBuilding' 'TallBuilding' 'bedroom'
#  'TallBuilding' 'TallBuilding' 'OpenCountry' 'Office' 'InsideCity'
#  'InsideCity' 'InsideCity' 'OpenCountry' 'InsideCity' 'OpenCountry'
#  'Street' 'store' 'bedroom' 'TallBuilding' 'Highway' 'Street' 'bedroom'
#  'Office' 'InsideCity' 'OpenCountry' 'Coast' 'Highway' 'Office' 'Highway'
#  'bedroom' 'kitchen' 'Mountain' 'Office' 'kitchen' 'Highway' 'Highway'
#  'TallBuilding' 'InsideCity' 'kitchen' 'Suburb' 'livingRoom' 'kitchen'
#  'Highway' 'Mountain' 'Mountain' 'livingRoom' 'Forest' 'Highway' 'Highway'
#  'Mountain' 'Coast' 'OpenCountry' 'Highway' 'Office' 'OpenCountry'
#  'Suburb' 'Street' 'kitchen' 'Suburb' 'Forest' 'industrial' 'Coast'
#  'Suburb' 'livingRoom' 'InsideCity' 'InsideCity' 'Coast' 'Suburb' 'Suburb'
#  'Street' 'Office' 'Street' 'Highway' 'InsideCity' 'Street' 'InsideCity'
#  'InsideCity' 'kitchen' 'livingRoom' 'Mountain' 'Office' 'bedroom'
#  'kitchen' 'kitchen' 'bedroom' 'bedroom' 'kitchen' 'Suburb' 'Suburb'
#  'bedroom' 'bedroom' 'kitchen' 'InsideCity' 'Office' 'industrial'
#  'kitchen' 'Street' 'InsideCity' 'Forest' 'Suburb' 'industrial' 'Coast'
#  'Highway' 'store' 'OpenCountry' 'Street' 'OpenCountry' 'industrial'
#  'kitchen' 'InsideCity' 'Mountain' 'livingRoom' 'store' 'bedroom' 'Street'
#  'Office' 'industrial' 'OpenCountry' 'Office' 'Office' 'TallBuilding'
#  'TallBuilding' 'livingRoom' 'industrial' 'TallBuilding' 'OpenCountry'
#  'Coast' 'Suburb' 'Highway' 'Mountain' 'InsideCity' 'Suburb' 'store'
#  'kitchen' 'kitchen' 'OpenCountry' 'livingRoom' 'TallBuilding'
#  'OpenCountry' 'kitchen' 'Coast' 'Highway' 'Suburb' 'Coast' 'bedroom'
#  'Mountain' 'OpenCountry' 'kitchen' 'bedroom' 'Suburb' 'Coast' 'bedroom'
#  'OpenCountry' 'InsideCity' 'Coast' 'Coast' 'kitchen' 'Office' 'Coast'
#  'OpenCountry' 'InsideCity' 'livingRoom' 'OpenCountry' 'kitchen'
#  'TallBuilding' 'Coast' 'Street' 'Highway' 'kitchen' 'Suburb' 'bedroom'
#  'Coast' 'Suburb' 'Coast' 'Office' 'Street' 'kitchen' 'kitchen' 'Suburb'
#  'Suburb' 'kitchen' 'kitchen' 'Office' 'livingRoom' 'OpenCountry' 'store'
#  'kitchen']

# %%
c = 0
for i in range(len(test_labels)):
    if test_labels[i] == predicted_categories[i]:
        c += 1
print("正确率：", c/450*100)
# Out:
# 正确率： 19.333333333333332

# %%
from skimage.feature import hog
from numpy.linalg import norm

def get_bags_of_words(image_paths):
    vocab = np.load('vocab.npy')
    print('Loaded vocab from file.')

    images = imread_collection(image_paths)
    images_histograms = []

    cells_per_block = (2, 2) # Change for lower compute time
    t = cells_per_block[0]
    pixels_per_cell = (4, 4)
    images_feature_vectors = []

    for i, image in enumerate(images):
        feature_vector = hog(
            image, 
            feature_vector = True, 
            pixels_per_cell = pixels_per_cell,
            cells_per_block = cells_per_block, 
            visualize = False
        ).reshape(-1, t*t*9)

        # 计算当前图片的feature与词袋的距离
        dist = cdist(vocab, feature_vector, metric='euclidean')

        # 选择最短距离，计算直方图
        min_dis_index = np.argmin(dist, axis=0)
        histogram, bin_edges = np.histogram(min_dis_index, bins=len(vocab))
        histogram = histogram / norm(histogram)

        images_histograms.append(histogram)

    return np.array(images_histograms)

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans
import time

def build_vocabulary(image_paths, vocab_size):
    images = imread_collection(image_paths)

    cells_per_block = (2, 2)
    pixels_per_cell = (4, 4)
    t = cells_per_block[0]
    images_feature_vectors = []

    for image in images:
        feature_vector = hog(
            image, 
            feature_vector = True, 
            pixels_per_cell = pixels_per_cell,
            cells_per_block = cells_per_block, 
            visualize = False
        ).reshape(-1, t*t*9)

        images_feature_vectors.append(feature_vector)

    images_feature_vectors = np.vstack(images_feature_vectors)

    # MiniBatchKMeans相比KMeans用时更少，资源消耗更少，质量相对要差一点，但差别不大
    t0 = time.time()
    k_means = KMeans(n_clusters=vocab_size, max_iter=5).fit(images_feature_vectors)
#     k_means = MiniBatchKMeans(n_clusters=vocab_size, max_iter=500).fit(images_feature_vectors)
    print('time spend：', time.time() - t0)

    vocabulary = np.vstack(k_means.cluster_centers_)

    return vocabulary

# %%
if not os.path.isfile('vocab.npy'):
    print('No existing visual word vocabulary found. Computing one from training images.')

    #Larger values will work better (to a point), but are slower to compute
    vocab_size = 200

    # YOU CODE build_vocabulary (see student.py)
    vocab = build_vocabulary(train_image_paths, vocab_size)
    np.save('vocab.npy', vocab)

# YOU CODE get_bags_of_words.m (see student.py)
train_image_feats = get_bags_of_words(train_image_paths)
# You may want to write out train_image_features here as a *.npy and
# load it up later if you want to just test your classifiers without
# re-computing features

test_image_feats  = get_bags_of_words(test_image_paths)
# Out:
# No existing visual word vocabulary found. Computing one from training images.
# time spend： 1244.657154083252
# Loaded vocab from file.
# Loaded vocab from file.

# %%
from sklearn.svm import LinearSVC

def svm_classify(train_image_feats, train_labels, test_image_feats):
    l_svc = LinearSVC(random_state=0, tol=1e-5)

    # train LinearSVC model
    l_svc.fit(train_image_feats, train_labels)

    # make prediction
    predictions = l_svc.predict(test_image_feats)

    return predictions

# %%
predicted_categories = svm_classify(train_image_feats, train_labels, test_image_feats)
print(predicted_categories)
# Out:
# ['kitchen' 'kitchen' 'kitchen' 'kitchen' 'kitchen' 'kitchen' 'kitchen'
#  'kitchen' 'kitchen' 'kitchen' 'kitchen' 'kitchen' 'kitchen' 'kitchen'
#  'kitchen' 'kitchen' 'Suburb' 'store' 'bedroom' 'bedroom' 'kitchen'
#  'kitchen' 'kitchen' 'bedroom' 'kitchen' 'kitchen' 'kitchen' 'kitchen'
#  'industrial' 'kitchen' 'store' 'store' 'Suburb' 'store' 'store' 'store'
#  'store' 'store' 'store' 'store' 'store' 'store' 'store' 'store' 'Office'
#  'store' 'store' 'store' 'store' 'store' 'store' 'store' 'store' 'store'
#  'store' 'Suburb' 'store' 'store' 'store' 'store' 'bedroom' 'kitchen'
#  'bedroom' 'Office' 'Highway' 'bedroom' 'bedroom' 'bedroom' 'bedroom'
#  'bedroom' 'bedroom' 'bedroom' 'Office' 'bedroom' 'bedroom' 'bedroom'
#  'bedroom' 'Suburb' 'kitchen' 'bedroom' 'Suburb' 'bedroom' 'bedroom'
#  'Suburb' 'kitchen' 'Suburb' 'OpenCountry' 'kitchen' 'kitchen' 'kitchen'
#  'livingRoom' 'OpenCountry' 'livingRoom' 'livingRoom' 'livingRoom'
#  'livingRoom' 'Coast' 'livingRoom' 'livingRoom' 'livingRoom' 'Coast'
#  'livingRoom' 'livingRoom' 'livingRoom' 'livingRoom' 'Street'
#  'TallBuilding' 'InsideCity' 'livingRoom' 'OpenCountry' 'OpenCountry'
#  'bedroom' 'InsideCity' 'livingRoom' 'OpenCountry' 'livingRoom' 'bedroom'
#  'livingRoom' 'OpenCountry' 'InsideCity' 'Office' 'Office' 'Office'
#  'Forest' 'store' 'Suburb' 'Office' 'Office' 'Office' 'Office' 'Office'
#  'Office' 'Office' 'Office' 'Office' 'Office' 'Office' 'Office' 'kitchen'
#  'Office' 'Office' 'Office' 'Office' 'Office' 'Suburb' 'store' 'bedroom'
#  'Office' 'store' 'InsideCity' 'industrial' 'industrial' 'industrial'
#  'industrial' 'industrial' 'industrial' 'Mountain' 'Street' 'industrial'
#  'industrial' 'industrial' 'industrial' 'industrial' 'industrial'
#  'industrial' 'industrial' 'industrial' 'industrial' 'industrial'
#  'industrial' 'industrial' 'Mountain' 'industrial' 'industrial'
#  'industrial' 'industrial' 'industrial' 'industrial' 'industrial'
#  'industrial' 'Suburb' 'Highway' 'Suburb' 'store' 'bedroom' 'store'
#  'kitchen' 'Suburb' 'Suburb' 'Suburb' 'Suburb' 'kitchen' 'Suburb' 'Suburb'
#  'Suburb' 'bedroom' 'store' 'Suburb' 'Suburb' 'Suburb' 'store' 'Suburb'
#  'Highway' 'kitchen' 'store' 'Suburb' 'kitchen' 'kitchen' 'kitchen'
#  'Suburb' 'InsideCity' 'livingRoom' 'InsideCity' 'InsideCity' 'InsideCity'
#  'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity'
#  'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity'
#  'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity'
#  'InsideCity' 'InsideCity' 'InsideCity' 'InsideCity' 'Street' 'InsideCity'
#  'Office' 'Street' 'InsideCity' 'InsideCity' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'TallBuilding' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'TallBuilding' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'Office' 'TallBuilding' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'TallBuilding' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'TallBuilding' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'TallBuilding' 'TallBuilding' 'TallBuilding'
#  'TallBuilding' 'TallBuilding' 'TallBuilding' 'Street' 'Street' 'Street'
#  'InsideCity' 'Street' 'Street' 'Street' 'Office' 'Street' 'Street'
#  'livingRoom' 'livingRoom' 'Street' 'livingRoom' 'Street' 'livingRoom'
#  'Street' 'store' 'Street' 'Street' 'InsideCity' 'Street' 'Street'
#  'bedroom' 'Street' 'livingRoom' 'InsideCity' 'InsideCity' 'Street'
#  'industrial' 'Coast' 'Coast' 'Mountain' 'Mountain' 'Mountain' 'Mountain'
#  'industrial' 'Mountain' 'bedroom' 'industrial' 'Mountain' 'industrial'
#  'Highway' 'Street' 'Highway' 'Coast' 'Highway' 'Highway' 'Mountain'
#  'Coast' 'industrial' 'Mountain' 'Mountain' 'Mountain' 'Mountain'
#  'industrial' 'InsideCity' 'Mountain' 'Mountain' 'Mountain' 'OpenCountry'
#  'OpenCountry' 'InsideCity' 'OpenCountry' 'OpenCountry' 'Coast'
#  'OpenCountry' 'OpenCountry' 'OpenCountry' 'OpenCountry' 'OpenCountry'
#  'InsideCity' 'OpenCountry' 'Suburb' 'OpenCountry' 'Forest' 'OpenCountry'
#  'OpenCountry' 'OpenCountry' 'OpenCountry' 'OpenCountry' 'OpenCountry'
#  'OpenCountry' 'OpenCountry' 'OpenCountry' 'OpenCountry' 'Highway'
#  'Forest' 'OpenCountry' 'OpenCountry' 'industrial' 'Coast' 'Highway'
#  'Coast' 'Coast' 'livingRoom' 'Coast' 'Coast' 'Highway' 'Coast' 'Coast'
#  'Forest' 'Forest' 'Coast' 'OpenCountry' 'Coast' 'OpenCountry' 'Coast'
#  'Coast' 'Coast' 'Coast' 'Coast' 'Coast' 'Coast' 'Coast' 'Highway'
#  'livingRoom' 'Coast' 'Coast' 'Coast' 'industrial' 'industrial' 'Mountain'
#  'industrial' 'Mountain' 'Mountain' 'Coast' 'livingRoom' 'Mountain'
#  'bedroom' 'livingRoom' 'TallBuilding' 'Street' 'Mountain' 'Mountain'
#  'industrial' 'Coast' 'Mountain' 'Highway' 'Mountain' 'Mountain'
#  'industrial' 'Highway' 'Mountain' 'Mountain' 'Mountain' 'industrial'
#  'Mountain' 'Mountain' 'Mountain' 'Forest' 'Forest' 'TallBuilding'
#  'Forest' 'livingRoom' 'Coast' 'Mountain' 'Street' 'Coast' 'Forest'
#  'Forest' 'Forest' 'Forest' 'Coast' 'Forest' 'Forest' 'Office' 'Office'
#  'OpenCountry' 'OpenCountry' 'Forest' 'Forest' 'TallBuilding' 'Forest'
#  'Forest' 'Forest' 'Forest' 'Mountain' 'Forest' 'Office']

# %%
c = 0
for i in range(len(test_labels)):
    if test_labels[i] == predicted_categories[i]:
        c += 1
print("正确率：", c/450*100)
# Out:
# 正确率： 65.77777777777779
